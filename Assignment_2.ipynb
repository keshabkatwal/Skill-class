# %% [markdown]
# ### Write a Python program using a lambda function to check if a given string is a palindrome.
#
# Example:
#
# Input: "level"
#
# Output: True

# %%
is_palindrome = lambda s: s == s[::-1]


string = input("Enter a string to check if it is a palindrome: ")


if is_palindrome(string):
    print(f'"{string}" is a palindrome.')
else:
    print(f'"{string}" is not a palindrome.')
# Out:
# "level" is a palindrome.

# %%
def is_armstrong_number(num):

    digits = str(num)

    num_digits = len(digits)

    armstrong_sum = sum(int(digit) ** num_digits for digit in digits)

    return armstrong_sum == num


while True:
    try:
        number = int(input("Enter a positive integer to check if it is an Armstrong number: "))
        if number < 0:
            raise ValueError("The number must be positive.")
        break
    except ValueError as e:
        print(e)


if is_armstrong_number(number):
    print(f"{number} is an Armstrong number.")
else:
    print(f"{number} is not an Armstrong number.")
# Out:
# 12 is not an Armstrong number.
